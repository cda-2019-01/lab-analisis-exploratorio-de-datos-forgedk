# %%
import pandas as pd
import glob

Archivos = glob.glob('Files/*')




DataFrameLectura = pd.read_excel("Files/Precio_Bolsa_Nacional_($kwh)_1995.xlsx",skipsrows =1, usecols = list(range(26)))
DataFrameLecturaCopia = DataFrameLectura.copy()
IndiceDelaColumnaFecha= DataFrameLecturaCopia[DataFrameLecturaCopia.columns[0]] == 'Fecha'

# %%
def LeerPrecios(filename):
    for indice in range(10):
        df = pd.read_excel(filename,skipsrows = indice, usecols = list(range(26)))
        if df.iloc[0,0] == 'Fecha':
            df = pd.read_excel(fiename,skipsrows = indice+1, usecols = list(range(26)))
            break
    return df

# %%
ArregloProcesado = LeerPrecios("Files/Precio_Bolsa_Nacional_($kwh)_1995.xlsx")
ArregloProcesado
# Out:
#                              Unnamed: 0  Unnamed: 1  Unnamed: 2  Unnamed: 3  \
# 0    Precio Bolsa Nacional ($/kWh) 1995         NaN         NaN         NaN
# 1                                   NaN         NaN         NaN         NaN
# 2                                 Fecha       0.000       1.000       2.000
# 3                            1995-07-20         NaN       1.073       1.073
# 4                            1995-07-21       1.073       1.000       1.000
# 5                            1995-07-22       1.073       1.073       1.000
# 6                            1995-07-23       1.073       1.000       1.000
# 7                            1995-07-24       1.000       1.000       0.990
# 8                            1995-07-25       0.990       0.990       0.989
# 9                            1995-07-26       0.500       0.500       0.500
# 10                           1995-07-27       0.500       0.500       0.500
# ...

# %%
def leer_precios(filename):
    for k in range(10):
        df = pd.read_excel(filename,
                           skiprows = k,
                           usecols = list(range(25)))
        if df.iloc[0,0] == 'Fecha':
            df = pd.read_excel(filename,
                               skiprows = k+1,
                               usecols = list(range(25)))
            break
        
    return(df)
    
    
    
  
filenames = !ls Files/*.xls*
dfs = []
for filename in filenames:
    dfs.append(leer_precios(filename))
dfs = pd.concat(dfs)
dfs.size
dfs = pd.melt(dfs,id_vars='Fecha')

# %%
dfs
# Out:
#              Fecha variable       value
# 0       1995-07-20        0         NaN
# 1       1995-07-21        0    1.073000
# 2       1995-07-22        0    1.073000
# 3       1995-07-23        0    1.073000
# 4       1995-07-24        0    1.000000
# 5       1995-07-25        0    0.990000
# 6       1995-07-26        0    0.500000
# 7       1995-07-27        0    0.500000
# 8       1995-07-28        0    0.000000
# 9       1995-07-29        0    1.000000
# 10      1995-07-30        0    1.072000
# 11      1995-07-31        0    0.000000
# 12      1995-08-01        0    0.000000
# 13      1995-08-02        0    1.073000
# 14      1995-08-03        0    1.073000
# 15      1995-08-04        0    1.073000
# 16      1995-08-05        0    2.000000
# 17      1995-08-06        0    3.000000
# 18      1995-08-07        0    3.000000
# 19      1995-08-08        0    3.000000
# 20      1995-08-09        0   10.000000
# 21      1995-08-10        0   18.000000
# ...
